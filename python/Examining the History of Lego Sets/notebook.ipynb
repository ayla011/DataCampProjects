# %% [markdown]
# ![star_wars_unsplash](star_wars_unsplash.jpg)
#
# Lego is a household name across the world, supported by a diverse toy line, hit movies, and a series of successful video games. In this project, we are going to explore a key development in the history of Lego: the introduction of licensed sets such as Star Wars, Super Heroes, and Harry Potter.
#
# The introduction of its first licensed series, Star Wars, was a hit that sparked a series of collaborations with more themed sets. The partnerships team has asked you to perform an analysis of this success, and before diving into the analysis, they have suggested reading the descriptions of the two datasets to use, reported below.
#
# ## The Data
#
# You have been provided with two datasets to use. A summary and preview are provided below.
#
# ## lego_sets.csv
#
# | Column     | Description              |
# |------------|--------------------------|
# | `"set_num"` | A code that is unique to each set in the dataset. This column is critical, and a missing value indicates the set is a duplicate or invalid! |
# | `"name"` | The name of the set. |
# | `"year"` | The date the set was released. |
# | `"num_parts"` | The number of parts contained in the set. This column is not central to our analyses, so missing values are acceptable. |
# | `"theme_name"` | The name of the sub-theme of the set. |
# | `"parent_theme"` | The name of the parent theme the set belongs to. Matches the name column of the parent_themes csv file.
# |
#
# ## parent_themes.csv
#
# | Column     | Description              |
# |------------|--------------------------|
# | `"id"` | A code that is unique to every theme. |
# | `"name"` | The name of the parent theme. |
# | `"is_licensed"` | A Boolean column specifying whether the theme is a licensed theme. |

# %%
# Import pandas, read and inspect the datasets
import pandas as pd

lego_sets = pd.read_csv('data/lego_sets.csv')
lego_sets.head()
# Out:
#   set_num                        name  ...    theme_name  parent_theme
# 0    00-1             Weetabix Castle  ...        Castle      Legoland
# 1  0011-2           Town Mini-Figures  ...  Supplemental          Town
# 2  0011-3  Castle 2 for 1 Bonus Offer  ...  Lion Knights        Castle
# 3  0012-1          Space Mini-Figures  ...  Supplemental         Space
# 4  0013-1          Space Mini-Figures  ...  Supplemental         Space
#
# [5 rows x 6 columns]

# %%
parent_themes = pd.read_csv('data/parent_themes.csv')
parent_themes.head()
# Out:
#     id     name  is_licensed
# 0    1  Technic        False
# 1   22  Creator        False
# 2   50     Town        False
# 3  112   Racers        False
# 4  126    Space        False

# %% [markdown]
# What percentage of all licensed sets ever released were Star Wars themed? Save your answer as a variable the_force, as an integer (e.g. 25).

# %%
#clean the data
lego_sets_clean = lego_sets.dropna(subset = ['set_num', 'name', 'theme_name'])
lego_sets_clean.head()
# Out:
#   set_num                        name  ...    theme_name  parent_theme
# 0    00-1             Weetabix Castle  ...        Castle      Legoland
# 1  0011-2           Town Mini-Figures  ...  Supplemental          Town
# 2  0011-3  Castle 2 for 1 Bonus Offer  ...  Lion Knights        Castle
# 3  0012-1          Space Mini-Figures  ...  Supplemental         Space
# 4  0013-1          Space Mini-Figures  ...  Supplemental         Space
#
# [5 rows x 6 columns]

# %%
#list of licensed themes 
licensed_themes = parent_themes[parent_themes['is_licensed']]['name']
licensed_themes.head()
# Out:
# 7                    Star Wars
# 12                Harry Potter
# 16    Pirates of the Caribbean
# 17               Indiana Jones
# 18                        Cars
# Name: name, dtype: object

# %%
#list of licensed sets ever released
licensed_sets = lego_sets_clean[lego_sets_clean['parent_theme'].isin(licensed_themes)]
licensed_sets.head()
# Out:
#     set_num  ...  parent_theme
# 44  10018-1  ...     Star Wars
# 45  10019-1  ...     Star Wars
# 54  10026-1  ...     Star Wars
# 57  10030-1  ...     Star Wars
# 95  10075-1  ...  Super Heroes
#
# [5 rows x 6 columns]

# %%
#list of star wars sets 
star_wars = lego_sets_clean[lego_sets_clean['parent_theme'].isin(['Star Wars'])]
star_wars.head()
# Out:
#      set_num  ... parent_theme
# 44   10018-1  ...    Star Wars
# 45   10019-1  ...    Star Wars
# 54   10026-1  ...    Star Wars
# 57   10030-1  ...    Star Wars
# 116  10123-1  ...    Star Wars
#
# [5 rows x 6 columns]

# %%
#percentage of star wars
num_star_wars = len(star_wars)
num_licensed = len(licensed_sets)
the_force = int((num_star_wars/num_licensed)*100)
print(str(the_force) + ' percent of all licensed sets ever released were Star Wars themed.')
# Out:
# 51 percent of all licensed sets ever released were Star Wars themed.

# %% [markdown]
# In which year was the highest number of Star Wars sets released? Save your answer as a variable new_era, as an integer (e.g. 2012).

# %%
#count the number of sets released per year
lego_sets_pivot = lego_sets_clean.pivot_table(index = 'year', columns = 'parent_theme', values = 'set_num', aggfunc = 'count')
new_era_df = lego_sets_pivot[lego_sets_pivot['Star Wars'] == lego_sets_pivot['Star Wars'].max()]['Star Wars']
new_era = 2016
print('The year with the highest number of Star Wars sets released was ' + str(new_era) + '.')
# Out:
# The year with the highest number of Star Wars sets released was 2016.
